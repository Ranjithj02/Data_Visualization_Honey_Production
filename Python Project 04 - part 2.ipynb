# %% [markdown]
# ## PART II:
# ## Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# ## Project 4

# %% [markdown]
# 1. Import required libraries and read the dataset. (2 marks)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

stock = pd.read_csv("honeyproduction.csv")

# %%
stock
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
#  2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features. (2 marks)

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
stock.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
stock.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
stock.shape
# Out:
# (626, 8)

# %%
stock.describe().T
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart. (2 marks)

# %%
import plotly.express as px
plt.pie(stock.year.value_counts(), autopct = '%.1f%%', radius = 1.0, labels = ['1998', '1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010','2011','2012'])
# display the plot
plt.title('Distribution of data in year')

plt.show()

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings. (2 marks)

# %%
sns.displot(stock["priceperlb"], kde=True)
plt.show()

# %% [markdown]
#         Above displot, In priceperlb variable most values in around 1 to 2 .

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings. (2 marks)

# %%
sns.scatterplot(x=stock["numcol"], y=stock["prodvalue"], data=stock)
plt.show()

# %% [markdown]
#          In above scatter plot is strong correlation values

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings. (2 marks)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=stock["year"], y=stock["prodvalue"],data = stock)
plt.show()

# %% [markdown]
#         In above boxplot compare the prodvalue vs year. In this 2010 year more amount of outlier occurs.
#         low amount of outlier in 1999

# %% [markdown]
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year') (2 marks)

# %%
sns.pairplot(stock, hue="year", vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year'])
plt.show()

# %% [markdown]
#     In the above pairplot , columns values are  'numcol', 'yield percol', 'total prod', 'prodvalue','year'.
#     In that plot  Dark colour values are High and light colour values are Low
#     And data are positive correlations

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue') (2 marks)

# %%
correlation = stock[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr ()  
correlation.style.background_gradient (cmap = 'BrBG')
# Out:
# <style type="text/css">
# #T_4fc91_row0_col0, #T_4fc91_row1_col1, #T_4fc91_row2_col2, #T_4fc91_row3_col3, #T_4fc91_row4_col4, #T_4fc91_row5_col5 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_4fc91_row0_col1 {
#   background-color: #f6eed9;
#   color: #000000;
# }
# #T_4fc91_row0_col2, #T_4fc91_row2_col0 {
#   background-color: #004b40;
#   color: #f1f1f1;
# }
# #T_4fc91_row0_col3 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_4fc91_row0_col4 {
#   background-color: #874e0a;
#   color: #f1f1f1;
# }
# #T_4fc91_row0_col5 {
#   background-color: #015d54;
#   color: #f1f1f1;
# }
# #T_4fc91_row1_col0 {
#   background-color: #f2e2b8;
#   color: #000000;
# }
# #T_4fc91_row1_col2 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_4fc91_row1_col3 {
#   background-color: #edf3f2;
#   color: #000000;
# }
# #T_4fc91_row1_col4, #T_4fc91_row4_col0, #T_4fc91_row4_col1, #T_4fc91_row4_col2, #T_4fc91_row4_col3, #T_4fc91_row4_col5 {
# ...

# %%
correlation = stock[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr()  
sns.heatmap(correlation,annot=True)


plt.show()

# %% [markdown]
#     In above heatmap is numcol and prodvalue is positive correlation.
#     Negative correlation  in priceperlb and yieldpercol
